# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
csvpath = Path('whale_returns.csv')
whale_df = pd.read_csv(csvpath)

# %%
# Confirming read_csv functioned properly
whale_df
# Out:
#             Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     2015-03-02                        NaN                 NaN
# 1     2015-03-03                  -0.001266           -0.004981
# 2     2015-03-04                   0.002230            0.003241
# 3     2015-03-05                   0.004016            0.004076
# 4     2015-03-06                  -0.007905           -0.003574
# ...          ...                        ...                 ...
# 1055  2019-04-25                  -0.000285           -0.001291
# 1056  2019-04-26                   0.008149            0.009162
# 1057  2019-04-29                   0.001254            0.002719
# 1058  2019-04-30                  -0.001295           -0.002211
# 1059  2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                             NaN                     NaN
# 1                       -0.000496               -0.006569
# ...

# %%
# Count nulls
whale_df.isna().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace=True)
whale_df.head(5)
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
# 3  2015-03-05                   0.004016            0.004076
# 4  2015-03-06                  -0.007905           -0.003574
# 5  2015-03-09                   0.000582            0.004225
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098
# 5                     0.005843               -0.001652

# %%
# Confirming changes in the dataframe, there is now 1059 rows vs. 1060 
whale_df.shape
# Out:
# (1059, 5)

# %%
# Settting "Date" as Index
whale_df.set_index(pd.to_datetime(whale_df['Date'], infer_datetime_format=True), inplace=True)
whale_df.head()
# Out:
#                   Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03  2015-03-03                  -0.001266           -0.004981
# 2015-03-04  2015-03-04                   0.002230            0.003241
# 2015-03-05  2015-03-05                   0.004016            0.004076
# 2015-03-06  2015-03-06                  -0.007905           -0.003574
# 2015-03-09  2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
# Dropping extra Date column
whale_df.drop(columns=['Date'], inplace=True)
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
csvpath = Path('algo_returns.csv')
algo_df = pd.read_csv(csvpath)

# %%
# Count nulls
algo_df.isnull().count()
# Out:
# Date      1241
# Algo 1    1241
# Algo 2    1241
# dtype: int64

# %%
# Drop nulls
algo_df.dropna(inplace=True)
algo_df.head(5)
# Out:
#           Date    Algo 1    Algo 2
# 6   2014-06-05  0.004062  0.013285
# 7   2014-06-06  0.001857  0.008284
# 8   2014-06-09 -0.005012  0.005668
# 9   2014-06-10  0.004406 -0.000735
# 10  2014-06-11  0.004760 -0.003761

# %%
# Confirming changes in the dataframe, there is now 1235 rows vs. 1241
algo_df.shape
# Out:
# (1235, 3)

# %%
# Settting "Date" as Index
algo_df.set_index(pd.to_datetime(algo_df['Date'], infer_datetime_format=True), inplace=True)
algo_df.head()
# Out:
#                   Date    Algo 1    Algo 2
# Date
# 2014-06-05  2014-06-05  0.004062  0.013285
# 2014-06-06  2014-06-06  0.001857  0.008284
# 2014-06-09  2014-06-09 -0.005012  0.005668
# 2014-06-10  2014-06-10  0.004406 -0.000735
# 2014-06-11  2014-06-11  0.004760 -0.003761

# %%
# Dropping extra date column
algo_df.drop(columns=['Date'], inplace=True)
algo_df.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
csvpath = Path('sp500_history.csv')
sp_df = pd.read_csv(csvpath)

# %%
# Confirming read_csv functioned properly
sp_df.head(5)
# Out:
#         Date     Close
# 0  23-Apr-19  $2933.68
# 1  22-Apr-19  $2907.97
# 2  18-Apr-19  $2905.03
# 3  17-Apr-19  $2900.45
# 4  16-Apr-19  $2907.06

# %%
# Check Data Types
sp_df.shape
# Out:
# (1649, 2)

# %%
# Count nulls (no nulls found)
sp_df.isnull().sum()
# Out:
# Date     0
# Close    0
# dtype: int64

# %%
# Dataframe unchanged since there was no nulls
sp_df.shape
# Out:
# (1649, 2)

# %%
# Fix Data Types
sp_df.set_index(pd.to_datetime(sp_df['Date'], infer_datetime_format=True), inplace=True)
sp_df.head()
# Out:
#                  Date     Close
# Date
# 2019-04-23  23-Apr-19  $2933.68
# 2019-04-22  22-Apr-19  $2907.97
# 2019-04-18  18-Apr-19  $2905.03
# 2019-04-17  17-Apr-19  $2900.45
# 2019-04-16  16-Apr-19  $2907.06

# %%
# Drop the extra date column
sp_df.drop(columns=['Date'], inplace=True)
sp_df.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Removing dollar sign with .str.replace
sp_df['Close'] = sp_df['Close'].str.replace(r'\W','')
print(sp_df.head(5))
# Out:
#              Close
# Date
# 2019-04-23  293368
# 2019-04-22  290797
# 2019-04-18  290503
# 2019-04-17  290045
# 2019-04-16  290706
# C:\Users\gerar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
# Changing object type to interger
sp_df['Close'] = sp_df["Close"].astype(int)

# %%
# Changing values to percent changes
sp_df = sp_df.pct_change()
sp_df.head(5)
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Dropping Nulls from due to pct_change conversion
sp_df.dropna(inplace=True)
sp_df.head(5)
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
# Rename `Close` Column to be specific to this portfolio.
columns = ["Market Close"]
sp_df.columns = columns
sp_df.head(5)
# Out:
#             Market Close
# Date
# 2019-04-22     -0.008764
# 2019-04-18     -0.001011
# 2019-04-17     -0.001577
# 2019-04-16      0.002279
# 2019-04-15     -0.000509

# %%
# Checking all dataframes
whale_df.head(5)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
algo_df.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %%
sp_df.head(5)
# Out:
#             Market Close
# Date
# 2019-04-22     -0.008764
# 2019-04-18     -0.001011
# 2019-04-17     -0.001577
# 2019-04-16      0.002279
# 2019-04-15     -0.000509

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df = pd.concat([whale_df, algo_df, sp_df], axis="columns", join="inner")
combined_df.head(5)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  Market Close
# Date
# 2015-03-03 -0.000949      0.004408
# 2015-03-04  0.002416     -0.001195
# 2015-03-05  0.004323      0.014378
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_df.plot(figsize=(20,10), title="Daily Returns")

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + combined_df).cumprod() - 1
cumulative_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.000962           -0.001755
# 2015-03-05                   0.004981            0.002314
# 2015-03-06                  -0.002963           -0.001269
# 2015-03-09                  -0.002383            0.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.003028               -0.002383 -0.010514
# 2015-03-05                    -0.000681                0.004327 -0.011459
# 2015-03-06                    -0.009156               -0.008828 -0.016359
# 2015-03-09                    -0.003367               -0.010466 -0.021717
#
#               Algo 2  Market Close
# Date
# 2015-03-03 -0.000949      0.004408
# 2015-03-04  0.001464      0.003208
# 2015-03-05  0.005794      0.017632
# ...

# %%
# Plot cumulative returns
cumulative_returns.plot(figsize=(20,10), title="Cumulative Returns of all Portfolios")

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_df.boxplot(figsize=(20,15))

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
volatility = combined_df.std()
volatility
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# Market Close                   0.008587
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp_risk = combined_df["Market Close"].std()

# Determine which portfolios are riskier than the S&P 500
combined_df.std() > sp_risk
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# Market Close                   False
# dtype: bool

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
volatility = combined_df.std() * np.sqrt(252)
volatility
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# Market Close                   0.136313
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
# Plot the rolling standard deviation
combined_df.rolling(window=21).std().plot(figsize=(20,15))

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
price_correlation = combined_df.corr()

# Display de correlation matrix
sns.heatmap(price_correlation, vmin=-1, vmax=1)

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance = combined_df['Algo 1'].cov(combined_df['Market Close'])
covariance
# Out:
# -2.223042551715513e-06

# %%
# Calculate variance of S&P 500
variance_sp = combined_df['Market Close'].var()
variance_sp
# Out:
# 7.373467552840434e-05

# %%
# Computing beta
Algo_one_beta = covariance / variance_sp
Algo_one_beta
# Out:
# -0.030149214542337606

# %%
# Plot Beta
rolling_covariance = combined_df['Algo 1'].rolling(window=60).cov(combined_df['Market Close'])
rolling_covariance.plot(figsize=(20, 10), title='Rolling 60-Day Covariance of Algo 1 vs. S&P 500')

# %%
rolling_variance = combined_df['Market Close'].rolling(window=60).var()
rolling_variance.plot(figsize=(20, 10), title='Rolling 60-Day Variance of Market Close')

# %%
# Calculate 30-day rolling beta of MSFT and plot the data
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of Algo 1')

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
risk_free_rate_path = Path("risk_free_rate.csv")
risk_free_df = pd.read_csv(risk_free_rate_path)

# %%
# Fix Data Types
risk_free_df.set_index(pd.to_datetime(risk_free_df['Date'], infer_datetime_format=True), inplace=True)
risk_free_df.head(5)
# Out:
#                   Date   rf_rate
# Date
# 1954-01-04  1954-01-04  0.000148
# 1954-01-05  1954-01-05  0.000142
# 1954-01-06  1954-01-06  0.000142
# 1954-01-07  1954-01-07  0.000146
# 1954-01-08  1954-01-08  0.000146

# %%
# Drop the extra date column
risk_free_df.drop(columns=['Date'], inplace=True)
risk_free_df.head()
# Out:
#              rf_rate
# Date
# 1954-01-04  0.000148
# 1954-01-05  0.000142
# 1954-01-06  0.000142
# 1954-01-07  0.000146
# 1954-01-08  0.000146

# %%
all_combined = pd.concat([whale_df, algo_df, sp_df, risk_free_df], axis='columns', join='inner')
all_combined.head(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# 2015-03-10                  -0.010263           -0.005341
# 2015-03-11                   0.004012            0.005163
# 2015-03-12                   0.008265            0.010272
# 2015-03-13                  -0.002497           -0.001428
# 2015-03-16                   0.007901            0.003583
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# ...

# %%
# Calculate Sharpe Ratio
sharpe_ratios = ((all_combined.mean()-all_combined['rf_rate'].mean()) * 252) / (all_combined.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.190407
# PAULSON & CO.INC.             -0.710552
# TIGER GLOBAL MANAGEMENT LLC   -0.289643
# BERKSHIRE HATHAWAY INC         0.506337
# Algo 1                         1.138814
# Algo 2                         0.297261
# Market Close                  -0.779208
# rf_rate                        0.000000
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# Plot sharpe ratios
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here:

# %% [markdown]
# Algo 1 and Algo 2 both have positive Sharpe Ratios.
# In General, Sharpe Ratios in the range of 1 and 2 is considered relatively good.
# Comparing these algo Sharpe Ratios to the Market, you can see that they outperformed the market.
# The only portfolio in positive Sharpe Ratio territory is Soros Fund Mgmt LLC. & Berkshire Hathway Inc.

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
#tsla_df = pd.read_csv('tsla_2019.csv')

tsla_df = pd.read_csv('tsla.csv', index_col="Date", parse_dates=True, infer_datetime_format=True)
tsla_df.head(5)
# Out:
#             Close
# Date
# 2019-01-02  62.02
# 2019-01-03  60.07
# 2019-01-04  63.54
# 2019-01-07  66.99
# 2019-01-08  67.07

# %%
# Reading data from 2nd stock
wday_df = pd.read_csv('wday.csv', index_col="Date", parse_dates=True, infer_datetime_format=True)
wday_df.head(5)
# Out:
#              Close
# Date
# 2019-01-02  159.74
# 2019-01-03  154.02
# 2019-01-04  163.35
# 2019-01-07  163.50
# 2019-01-08  166.95

# %%
# Reading data from 3rd stock
nvda_df = pd.read_csv('nvda.csv', index_col="Date", parse_dates=True, infer_datetime_format=True)
nvda_df.head(5)
# Out:
#             Close
# Date
# 2019-01-02  34.06
# 2019-01-03  32.00
# 2019-01-04  34.05
# 2019-01-07  35.85
# 2019-01-08  34.96

# %%
# Combine all stocks in a single DataFrame
my_combined_df = pd.concat([nvda_df, wday_df, tsla_df], axis="columns", join="inner")

# Display a few rows
my_combined_df.head()
# Out:
#             Close   Close  Close
# Date
# 2019-01-02  34.06  159.74  62.02
# 2019-01-03  32.00  154.02  60.07
# 2019-01-04  34.05  163.35  63.54
# 2019-01-07  35.85  163.50  66.99
# 2019-01-08  34.96  166.95  67.07

# %%
# Reorganize portfolio data by having a column per symbol
my_combined_df.columns = ['NVDA', 'WDAY','TSLA']
my_combined_df.head()
# Out:
#              NVDA    WDAY   TSLA
# Date
# 2019-01-02  34.06  159.74  62.02
# 2019-01-03  32.00  154.02  60.07
# 2019-01-04  34.05  163.35  63.54
# 2019-01-07  35.85  163.50  66.99
# 2019-01-08  34.96  166.95  67.07

# %%
# Calculate daily returns, drop nulls
my_daily_returns = my_combined_df.pct_change().dropna()
my_daily_returns.head()
# Out:
#                 NVDA      WDAY      TSLA
# Date
# 2019-01-03 -0.060482 -0.035808 -0.031441
# 2019-01-04  0.064062  0.060577  0.057766
# 2019-01-07  0.052863  0.000918  0.054297
# 2019-01-08 -0.024826  0.021101  0.001194
# 2019-01-09  0.019737 -0.004612  0.009542

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [.333, .333, .333] # Set weights

# Calculate portfolio return
portfolio_returns = my_daily_returns.dot(weights) 

# Display sample data
portfolio_returns.head(5)
# Out:
# Date
# 2019-01-03   -0.042534
# 2019-01-04    0.060741
# 2019-01-07    0.035990
# 2019-01-08   -0.000843
# 2019-01-09    0.008214
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

new_df = pd.concat([all_combined, portfolio_returns], axis="columns", join="inner")
new_df.head(5)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-01-03                  -0.007848           -0.007403
# 2019-01-04                   0.029881            0.027032
# 2019-01-07                   0.009051            0.014475
# 2019-01-08                   0.010760            0.008050
# 2019-01-09                   0.008630           -0.000800
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-01-03                    -0.008478               -0.032053  0.015246
# 2019-01-04                     0.033560                0.061341  0.017622
# 2019-01-07                     0.014111                0.017185  0.014748
# 2019-01-08                     0.001544                0.005851  0.010825
# 2019-01-09                    -0.000534                0.019788  0.000214
#
#               Algo 2  Market Close   rf_rate         0
# Date
# 2019-01-03 -0.011792     -0.033196  0.000262 -0.042534
# ...

# %%
new_df.columns = ['SOROS FUND MANAGEMENT LLC', 'PAULSON & CO.INC.','TIGER GLOBAL MANAGEMENT LLC','BERKSHIRE HATHAWAY INC','Algo 1','Algo 2','Market Close','rf_rate','My Portfolio']
new_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# Date
# 2019-01-03                  -0.007848          -0.007403
# 2019-01-04                   0.029881           0.027032
# 2019-01-07                   0.009051           0.014475
# 2019-01-08                   0.010760           0.008050
# 2019-01-09                   0.008630          -0.000800
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-01-03                    -0.008478               -0.032053  0.015246
# 2019-01-04                     0.033560                0.061341  0.017622
# 2019-01-07                     0.014111                0.017185  0.014748
# 2019-01-08                     0.001544                0.005851  0.010825
# 2019-01-09                    -0.000534                0.019788  0.000214
#
#               Algo 2  Market Close   rf_rate  My Portfolio
# Date
# 2019-01-03 -0.011792     -0.033196  0.000262     -0.042534
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
new_df.dropna(inplace=True)
new_df.head(5)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# Date
# 2019-01-03                  -0.007848          -0.007403
# 2019-01-04                   0.029881           0.027032
# 2019-01-07                   0.009051           0.014475
# 2019-01-08                   0.010760           0.008050
# 2019-01-09                   0.008630          -0.000800
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-01-03                    -0.008478               -0.032053  0.015246
# 2019-01-04                     0.033560                0.061341  0.017622
# 2019-01-07                     0.014111                0.017185  0.014748
# 2019-01-08                     0.001544                0.005851  0.010825
# 2019-01-09                    -0.000534                0.019788  0.000214
#
#               Algo 2  Market Close   rf_rate  My Portfolio
# Date
# 2019-01-03 -0.011792     -0.033196  0.000262     -0.042534
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annualized_std = new_df.std() * np.sqrt(252)
annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.119063
# PAULSON & CO.INC.              0.111101
# TIGER GLOBAL MANAGEMENT LLC    0.291573
# BERKSHIRE HATHAWAY INC         0.204862
# Algo 1                         0.091311
# Algo 2                         0.121633
# Market Close                   0.114623
# rf_rate                        0.000036
# My Portfolio                   0.315250
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation

# Plot rolling standard deviation
new_df.rolling(window=21).std().plot(figsize=(20,15))

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
price_correlation = new_df.corr()

# Display de correlation matrix
sns.heatmap(price_correlation, vmin=-1, vmax=1)

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta

covariance = new_df['My Portfolio'].cov(new_df['Market Close'])
covariance
# Out:
# 1.148420658266763e-05

# %%
# Calculate variance of S&P 500
variance_sp = new_df['Market Close'].var()
variance_sp
# Out:
# 5.213645147041288e-05

# %%
# Computing beta
Algo_one_beta = covariance / variance_sp
Algo_one_beta
# Out:
# 0.22027211785184206

# %%
# Plot Beta
rolling_covariance = new_df['My Portfolio'].rolling(window=60).cov(new_df['Market Close'])
rolling_covariance.plot(figsize=(20, 10), title='Rolling 60-Day Covariance of My Portfolio vs. S&P 500')

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratios = ((new_df.mean()-new_df['rf_rate'].mean()) * 252) / (new_df.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      4.282186
# PAULSON & CO.INC.              1.674692
# TIGER GLOBAL MANAGEMENT LLC   -0.690864
# BERKSHIRE HATHAWAY INC         3.944332
# Algo 1                         2.606421
# Algo 2                         4.299891
# Market Close                  -5.826579
# rf_rate                        0.000000
# My Portfolio                   1.260520
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %% [markdown]
# My Portfolio performed around at around 1.5 sharpe ratio. In the given time frame, it performed a little better than the overall market.
